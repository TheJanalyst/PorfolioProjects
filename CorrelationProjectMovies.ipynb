# %%
# Import Libraries
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #Adjusts the configuration of the plots we will create

#Read in the data

df = pd.read_csv(r'C:\Users\jkata\OneDrive\Pulpit\Data Analyst Portfolio Project\movies.csv', encoding='latin-1')

# %%
df.head()
# Out:
#        budget                                 company country        director  \
# 0   8000000.0           Columbia Pictures Corporation     USA      Rob Reiner
# 1   6000000.0                      Paramount Pictures     USA     John Hughes
# 2  15000000.0                      Paramount Pictures     USA      Tony Scott
# 3  18500000.0  Twentieth Century Fox Film Corporation     USA   James Cameron
# 4   9000000.0                    Walt Disney Pictures     USA  Randal Kleiser
#
#        genre        gross                      name rating    released  \
# 0  Adventure   52287414.0               Stand by Me      R  1986-08-22
# 1     Comedy   70136369.0  Ferris Bueller's Day Off  PG-13  1986-06-11
# 2     Action  179800601.0                   Top Gun     PG  1986-05-16
# 3     Action   85160248.0                    Aliens      R  1986-07-18
# 4  Adventure   18564613.0   Flight of the Navigator     PG  1986-08-01
#
#    runtime  score               star   votes         writer  year
# 0       89    8.1        Wil Wheaton  299174   Stephen King  1986
# 1      103    7.8  Matthew Broderick  264740    John Hughes  1986
# 2      110    6.9         Tom Cruise  236909       Jim Cash  1986
# 3      137    8.4   Sigourney Weaver  540152  James Cameron  1986
# 4       90    6.9        Joey Cramer   36636  Mark H. Baker  1986

# %%
#Let's see if there is any missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# budget - 0.0%
# company - 0.0%
# country - 0.0%
# director - 0.0%
# genre - 0.0%
# gross - 0.0%
# name - 0.0%
# rating - 0.0%
# released - 0.0%
# runtime - 0.0%
# score - 0.0%
# star - 0.0%
# votes - 0.0%
# writer - 0.0%
# year - 0.0%

# %%
#Data types four columns
df.dtypes
# Out:
# budget      float64
# company      object
# country      object
# director     object
# genre        object
# gross       float64
# name         object
# rating       object
# released     object
# runtime       int64
# score       float64
# star         object
# votes         int64
# writer       object
# year          int64
# dtype: object

# %%
# change data type
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df.head()
# Out:
#      budget                                 company country        director  \
# 0   8000000           Columbia Pictures Corporation     USA      Rob Reiner
# 1   6000000                      Paramount Pictures     USA     John Hughes
# 2  15000000                      Paramount Pictures     USA      Tony Scott
# 3  18500000  Twentieth Century Fox Film Corporation     USA   James Cameron
# 4   9000000                    Walt Disney Pictures     USA  Randal Kleiser
#
#        genre      gross                      name rating    released  runtime  \
# 0  Adventure   52287414               Stand by Me      R  1986-08-22       89
# 1     Comedy   70136369  Ferris Bueller's Day Off  PG-13  1986-06-11      103
# 2     Action  179800601                   Top Gun     PG  1986-05-16      110
# 3     Action   85160248                    Aliens      R  1986-07-18      137
# 4  Adventure   18564613   Flight of the Navigator     PG  1986-08-01       90
#
#    score               star   votes         writer  year
# 0    8.1        Wil Wheaton  299174   Stephen King  1986
# 1    7.8  Matthew Broderick  264740    John Hughes  1986
# 2    6.9         Tom Cruise  236909       Jim Cash  1986
# 3    8.4   Sigourney Weaver  540152  James Cameron  1986
# 4    6.9        Joey Cramer   36636  Mark H. Baker  1986

# %%
df['YearCorrect'] = df['released'].astype(str).str[:4]
df.head()
# Out:
#      budget                                 company country        director  \
# 0   8000000           Columbia Pictures Corporation     USA      Rob Reiner
# 1   6000000                      Paramount Pictures     USA     John Hughes
# 2  15000000                      Paramount Pictures     USA      Tony Scott
# 3  18500000  Twentieth Century Fox Film Corporation     USA   James Cameron
# 4   9000000                    Walt Disney Pictures     USA  Randal Kleiser
#
#        genre      gross                      name rating    released  runtime  \
# 0  Adventure   52287414               Stand by Me      R  1986-08-22       89
# 1     Comedy   70136369  Ferris Bueller's Day Off  PG-13  1986-06-11      103
# 2     Action  179800601                   Top Gun     PG  1986-05-16      110
# 3     Action   85160248                    Aliens      R  1986-07-18      137
# 4  Adventure   18564613   Flight of the Navigator     PG  1986-08-01       90
#
#    score               star   votes         writer  year YearCorrect
# 0    8.1        Wil Wheaton  299174   Stephen King  1986        1986
# 1    7.8  Matthew Broderick  264740    John Hughes  1986        1986
# 2    6.9         Tom Cruise  236909       Jim Cash  1986        1986
# 3    8.4   Sigourney Weaver  540152  James Cameron  1986        1986
# 4    6.9        Joey Cramer   36636  Mark H. Baker  1986        1986

# %%
df.sort_values(by=['budget'], inplace=False, ascending=False)
# Out:
#          budget                        company      country        director  \
# 4631  300000000           Walt Disney Pictures          USA  Gore Verbinski
# 5293  260000000  Walt Disney Animation Studios          USA    Nathan Greno
# 4637  258000000              Columbia Pictures          USA       Sam Raimi
# 6624  250000000                 Marvel Studios          USA   Anthony Russo
# 6194  250000000                New Line Cinema  New Zealand   Peter Jackson
# ...         ...                            ...          ...             ...
# 4976          0                Armian Pictures          USA  Jonathan Demme
# 4977          0      Enlightenment Productions           UK    Shamim Sarif
# 1746          0       Les Productions Lazennec       France   Tran Anh Hung
# 4979          0                       Fandango        Italy  Matteo Garrone
# 6819          0      Les Productions du Trésor       France   Nicole Garcia
#
#           genre      gross                                       name  \
# 4631     Action  309420425   Pirates of the Caribbean: At World's End
# 5293  Animation  200821936                                    Tangled
# 4637     Action  336530303                               Spider-Man 3
# 6624     Action  408084349                 Captain America: Civil War
# 6194  Adventure  255119788  The Hobbit: The Battle of the Five Armies
# ...         ...        ...                                        ...
# 4976      Drama   12796277                     Rachel Getting Married
# 4977      Drama      39373                     I Can't Think Straight
# 1746      Drama    1910763                  The Scent of Green Papaya
# 4979      Crime    1577639                                   Gomorrah
# 6819      Drama      37757                  From the Land of the Moon
#
#          rating    released  runtime  score                 star   votes  \
# 4631      PG-13  2007-05-25      169    7.1          Johnny Depp  514191
# 5293         PG  2010-11-24      100    7.8          Mandy Moore  325621
# 4637      PG-13  2007-05-04      139    6.2        Tobey Maguire  416842
# 6624      PG-13  2016-05-06      147    7.9          Chris Evans  442645
# 6194      PG-13  2014-12-17      144    7.4         Ian McKellen  396797
# ...         ...         ...      ...    ...                  ...     ...
# 4976          R  2008-11-07      113    6.7        Anne Hathaway   42934
# 4977      PG-13     2008-11       82    6.7             Lisa Ray    6352
# 1746  NOT RATED  1994-01-28      104    7.4      Tran Nu Yên-Khê    6642
# 4979  NOT RATED  2009-04-10      137    7.0  Gianfelice Imparato   40616
# 6819          R  2017-07-28      120    6.7     Marion Cotillard    2411
#
#                   writer  year YearCorrect
# 4631         Ted Elliott  2007        2007
# 5293        Dan Fogelman  2010        2010
# 4637           Sam Raimi  2007        2007
# 6624  Christopher Markus  2016        2016
# 6194          Fran Walsh  2014        2014
# ...                  ...   ...         ...
# 4976         Jenny Lumet  2008        2008
# 4977        Shamim Sarif  2008        2008
# 1746       Tran Anh Hung  1993        1994
# 4979     Roberto Saviano  2008        2009
# 6819         Milena Agus  2016        2017
#
# [6820 rows x 16 columns]

# %%
pd.set_option('display.max_rows',None)

# %%
# Budget high correlation
# Company high correlation

# %%
# Scatter plot with budget vs gross

plt.scatter(x=df['budget'],y=df['gross'])
plt.title ('Budget vs Gross Earnings')
plt.xlabel('Budget')
plt.ylabel('Gross Earnings')
plt.show()

# %%
# Plot budget vs gross using seaborn
sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color':'red'},line_kws={'color':'black'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
df.corr(method='pearson') #Pearson, Kendall, Spearman
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.712196  0.268226  0.042145  0.503924  0.291009
# gross    0.712196  1.000000  0.224579  0.165693  0.662457  0.191548
# runtime  0.268226  0.224579  1.000000  0.395343  0.317399  0.087639
# score    0.042145  0.165693  0.395343  1.000000  0.393607  0.105276
# votes    0.503924  0.662457  0.317399  0.393607  1.000000  0.229304
# year     0.291009  0.191548  0.087639  0.105276  0.229304  1.000000

# %%
# High correlation between budget and gross

correlation_matrix = df.corr(method='pearson') 
sns.heatmap(correlation_matrix,annot=True)
plt.show()

# %%
#look at company
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
df_numerized.head()
# Out:
#      budget  company  country  director  genre      gross  name  rating  \
# 0   8000000      665       54      2192      1   52287414  4661       8
# 1   6000000     1680       54      1296      4   70136369  1821       7
# 2  15000000     1680       54      2645      0  179800601  6203       6
# 3  18500000     2062       54      1066      0   85160248   295       8
# 4   9000000     2122       54      2123      1   18564613  1872       6
#
#    released  runtime  score  star   votes  writer  year  YearCorrect
# 0        39       89    8.1  2454  299174    3716  1986            0
# 1        27      103    7.8  1605  264740    1970  1986            0
# 2        23      110    6.9  2345  236909    1852  1986            0
# 3        33      137    8.4  2192  540152    1629  1986            0
# 4        36       90    6.9  1139   36636    2549  1986            0

# %%
correlation_matrix = df_numerized.corr(method='pearson') 
sns.heatmap(correlation_matrix,annot=True)
plt.title ('Corr. matric for numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()
plt.show()
